# %%
import requests
import pandas as pd
import numpy as np

from datetime import date, datetime, timedelta
from src.utils import get_config, Logger

import src.Stock as Stock

config = get_config()
log = Logger()
url = f"https://financialmodelingprep.com/api/v3"
apikey = f"&apikey={config['credentials']['financialmodelingprep']}"

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
str(date.today())

# %%
ee = Stock.Stock.get_earnings_events("MSFT")
a = Stock.Stock.get_prices(ee[1])
Stock.Stock.get_rsi(a)
Stock.Stock.get_stdev(a)
Stock.Stock.get_1wk_return(a)

# %%
a.round(2)
# Out:
#                   date    open    high     low   close  volume symbol  \
# date
# 2021-03-15  2021-03-15  234.96  235.19  231.81  234.81    0.56   MSFT
# 2021-03-16  2021-03-16  236.28  240.06  235.94  237.71    0.60   MSFT
# 2021-03-17  2021-03-17  236.15  238.55  233.23  237.04    0.63   MSFT
# 2021-03-18  2021-03-18  232.56  234.19  230.33  230.72    0.74   MSFT
# 2021-03-19  2021-03-19  231.02  232.47  229.35  230.35    0.99   MSFT
# 2021-03-22  2021-03-22  230.27  236.90  230.14  235.99    0.64   MSFT
# 2021-03-23  2021-03-23  237.49  241.05  237.07  237.58    0.67   MSFT
# 2021-03-24  2021-03-24  237.85  238.00  235.32  235.46    0.55   MSFT
# 2021-03-25  2021-03-25  235.30  236.94  231.57  232.34    0.73   MSFT
# 2021-03-26  2021-03-26  231.55  236.71  231.55  236.48    0.54   MSFT
# 2021-03-29  2021-03-29  236.59  236.80  231.88  235.24    0.54   MSFT
# 2021-03-30  2021-03-30  233.53  233.85  231.10  231.85    0.53   MSFT
# 2021-03-31  2021-03-31  232.91  239.10  232.39  235.77    0.93   MSFT
# 2021-04-01  2021-04-01  238.47  242.84  238.05  242.35    0.65   MSFT
# 2021-04-05  2021-04-05  242.76  249.96  242.70  249.07    0.79   MSFT
# 2021-04-06  2021-04-06  247.61  249.40  246.88  247.86    0.49   MSFT
# 2021-04-07  2021-04-07  247.81  250.93  247.19  249.90    0.48   MSFT
# 2021-04-08  2021-04-08  252.77  254.14  252.00  253.25    0.50   MSFT
# 2021-04-09  2021-04-09  252.87  255.99  252.44  255.85    0.52   MSFT
# 2021-04-12  2021-04-12  254.71  257.67  254.62  255.91    0.58   MSFT
# 2021-04-13  2021-04-13  257.26  259.19  256.83  258.49    0.51   MSFT
# 2021-04-14  2021-04-14  257.48  258.83  255.16  255.59    0.49   MSFT
# 2021-04-15  2021-04-15  257.93  259.93  257.73  259.50    0.55   MSFT
# 2021-04-16  2021-04-16  259.47  261.00  257.60  260.74    0.53   MSFT
# 2021-04-19  2021-04-19  260.19  261.48  257.82  258.74    0.49   MSFT
# 2021-04-20  2021-04-20  257.82  260.20  256.84  258.26    0.42   MSFT
# 2021-04-21  2021-04-21  258.94  260.68  257.25  260.58    0.51   MSFT
# 2021-04-22  2021-04-22  260.21  261.78  255.64  257.17    0.55   MSFT
# 2021-04-23  2021-04-23  257.88  261.51  257.27  261.15    0.46   MSFT
# 2021-04-26  2021-04-26  261.66  262.44  260.17  261.55    0.42   MSFT
# 2021-04-27  2021-04-27  261.58  263.19  260.12  261.97    0.66   MSFT
# 2021-04-28  2021-04-28  256.08  256.54  252.95  254.56    1.00   MSFT
# 2021-06-29  2021-04-28      0.12              62   73.30       1.46
# 2021-06-30  2021-04-28      0.12              63   71.93       1.25
# 2021-07-01  2021-04-28      0.12              64   72.71       1.20
# 2021-07-02  2021-04-28      0.12              65   78.29       1.60
# 2021-07-06  2021-04-28      0.12              69   78.30       1.40
# 2021-07-07  2021-04-28      0.12              70   80.10       1.42
# 2021-07-08  2021-04-28      0.12              71   72.88       1.08
# 2021-07-09  2021-04-28      0.12              72   73.42       1.03
# 2021-07-12  2021-04-28      0.12              75   71.58       0.90
# 2021-07-13  2021-04-28      0.12              76   75.50       1.12
# 2021-07-14  2021-04-28      0.12              77   76.93       1.14
# 2021-07-15  2021-04-28      0.12              78   72.48       0.93
# 2021-07-16  2021-04-28      0.12              79   71.63       0.84
# 2021-07-19  2021-04-28      0.12              82   61.23       0.49
# 2021-07-20  2021-04-28      0.12              83   64.66       0.66
# 2021-07-21  2021-04-28      0.12              84   67.47       0.80
# 2021-07-22  2021-04-28      0.12              85   72.81       1.13
# 2021-07-23  2021-04-28      0.12              86   75.99       1.29
# 2021-07-26  2021-04-28      0.12              89   74.33       1.12
# 2021-07-27  2021-04-28      0.12              90   67.86       0.84

# %%
a

# %%
d = pd.to_datetime(a.iloc[0].date) - pd.Timestamp.today()

# %%
d> timedelta(weeks=13)

# %%
def _to_Date(dt: str) -> datetime.date:
    return datetime.strptime(dt, '%Y-%m-%d').date()

# %%
import pickle

# %%
with open(f"data/screened_symbols.pickle", 'rb') as f:
    earnings_info = pickle.load(f)

# %%
len(earnings_info)

# %%
str((pd.to_datetime('2021-04-28') - timedelta(days=90)).date())

# %%
import requests
import pandas as pd
import pickle
from datetime import date, datetime, timedelta
from src.utils import get_config, Logger

# %%
config = get_config()
log = Logger()
today = date.today()
symbol='EGOV'
from_date='2020-11-01'

# %%
log.info(f"Fetching updated data for {symbol}.")
r = requests.get(f"https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}?from={from_date}&to={today}&apikey={config['credentials']['financialmodelingprep']}")
r.json()
df = pd.json_normalize(r.json())
history = df['historical'].values[0]
hist_df = pd.json_normalize(history)
hist_df 

#= hist_df.drop(['adjClose', 'change', 'unadjustedVolume', 'changePercent', 'vwap', 'label', 'changeOverTime'], axis=1)
#hist_df = hist_df.sort_values('date', ascending=True)

# %%
exp_span = 60
ema = hist_df['close'].ewm(span=exp_span, adjust=False).mean().round(2)
emstd = hist_df['close'].ewm(span=exp_span, adjust=False).std().round(4)
boll_low = (ema - 2*emstd).round(2)
boll_sig = hist_df['low'] < boll_low
boll_sig_lag_1 = boll_sig.shift(1)
boll_sig_lag_2 = boll_sig.shift(2)
hist_df['boll'] = ~boll_sig & boll_sig_lag_1 & boll_sig_lag_2

# %%
change = hist_df['close'].diff()
up = change.clip(lower=0)
down = -1 * change.clip(upper=0)
ema_up = up.ewm(span=13, adjust=False).mean()
ema_down = down.ewm(span=13, adjust=False).mean()
rs = ema_up/ema_down
rsi = 100 - (100/(1+rs))
rsi_sig = rsi < 25
rsi_sig_lag_1 = rsi_sig.shift(1)
rsi_sig_lag_2 = rsi_sig.shift(2)
hist_df['rsi_sig'] = ~rsi_sig & rsi_sig_lag_1 & rsi_sig_lag_2

# %%
ema_sig_span = 4
ema_sig = hist_df['close'] < hist_df['close'].ewm(span=ema_sig_span, adjust=False).mean().round(2)
ema_sig_lag_1 = ema_sig.shift(1)
ema_sig_lag_2 = ema_sig.shift(2)
hist_df['ema_sig'] = ~ema_sig & ema_sig_lag_1 & ema_sig_lag_2

# %%
buy_signal = hist_df[hist_df['boll'] & hist_df['rsi_sig'] & hist_df['ema_sig']]

# %%
buy_dates = buy_signal['date'].values

# %%
with open(f"data/signals.pickle", 'rb') as f:
    signals = pickle.load(f)

# %%
signal_list = []

# %%
for symbol, earnings_dates in signals.items():
    for earnings_date, signal_dates in earnings_dates.items():
        for signal in signal_dates:
            if signal > earnings_date:
                signal_list.append((symbol, signal))

# %%
def get_open_price(symbol, date):
    from_date = date #str((pd.to_datetime(date) - timedelta(days=1)).date())
    to_date = str((pd.to_datetime(date) + timedelta(days=3)).date())
    
    r = requests.get(f"https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}?from={from_date}&to={to_date}&apikey={config['credentials']['financialmodelingprep']}")
    r.json()
    df = pd.json_normalize(r.json())
    history = df['historical'].values[0]
    hist_df = pd.json_normalize(history)
    hist_df = hist_df.sort_values('date', ascending=True)
    
    if date in hist_df['date'].values:
        return hist_df[hist_df['date'] == date]['open'].values[0].round(2)
    else:
        return hist_df['open'].values[0].round(2)

# %%
get_open_price("WMT", "2021-08-16")

# %%
with open(f"{config['config']['data']}/signal_analysis.pickle", 'rb') as f:
            signal_perf = pickle.load(f)

# %%
perf = pd.DataFrame(data=signal_perf)

# %%
perf['surprise'] = ((perf['eps'] - perf['estimated']) / perf['estimated']).round(3) * 100

# %%
signal_perf.sort_values

# %%
signal_perf['gain_21'].mean()

# %%
perf['gain_28'].mean()

# %%
def _filter(x):
    if '2020-03' in x:
        return False
    else:
        return True

# %%
perf['marketCap'] = [get_market_cap(x,y) for x,y in zip(perf['symbol'], perf['signal_date'])]

# %%
filtered_perf = perf[[_filter(x) for x in perf['signal_date']]].sort_values('gain_21', ascending=False)

# %%
beats = filtered_perf[filtered_perf['surprise'] < -70]

# %%
beats['gain_21'].mean()

# %%
import matplotlib.pyplot as plt

plt.scatter(beats['surprise'], beats['gain_21'])
plt.xlim([-100,0])
plt.xlabel('surprise')
plt.ylim([-25,25])
plt.ylabel('% Gain Relative to S&P')

plt.show()

# %%
def get_market_cap(symbol, date):
    r = requests.get(f"https://financialmodelingprep.com/api/v3/historical-market-capitalization/{symbol}?limit=1000&apikey={config['credentials']['financialmodelingprep']}")
    r.json()
    df = pd.json_normalize(r.json())
    df = df[df['date'] == date]
    try:
        cap = int(df['marketCap'].values[0]) / 1000000000  
    except Exception as e:
        cap = None
        
    return cap

# %%
signal_perf['marketCap'] = [get_market_cap(s,d) for s,d in (zip(signal_perf['symbol'].values, signal_perf['date'].values))]

# %%
signal_perf.sort_values('marketCap', ascending=False)

# %%
import matplotlib.pyplot as plt

plt.scatter(signal_perf['marketCap'], signal_perf['gain_21'])
plt.xlim([0,100])
plt.xlabel('Market Cap (Billions)')
plt.ylim([-20,20])
plt.ylabel('% Gain Relative to S&P')

plt.show()
